# %%
# ! pip install spacy
# ! pip install spacy-transformers
import spacy
import spacy_transformers

# %%
# spacy.cli.download("en_core_web_trf")
import spacy
nlp = spacy.load("en_core_web_trf")
import en_core_web_trf
nlp = en_core_web_trf.load()
doc = nlp("This is a sentence.")
print([(w.text, w.pos_) for w in doc])

# %%
#!python -m spacy download en_core_web_trf
# !python -m spacy download curated_transformer
import spacy
nlp = spacy.load("en_core_web_trf")
import en_core_web_trf
nlp = en_core_web_trf.load()
doc = nlp("This is a sentence.")
print([(w.text, w.pos_) for w in doc])

# %%
! pip install spacy
! python -m spacy download en_core_web_sm
! python -m spacy download en
# ! python -m spacy download en_core_web_trf-3.7.2
import spacy
load_model = spacy.load("en_core_web_sm")
doc = load_model("Hi my name is mak")

# %%
load_model = spacy.load("en_core_web_sm")
doc = load_model("Hi my name is mak")

# %%
doc

# %%
# Functions
# dictionary[''] = ''
dictionary = {}
dictionary['ABS'] = 'Function: Returns the absolute value of a number'
dictionary['ASC'] = 'Function: Returns the ASCII decimal value of the first character in a string'
dictionary['ATN'] = 'Function: Returns the arctangent of a number'
dictionary['ATTACH'] = 'Function: Returns a Boolean integer value indicating whether or not a specified printer is available for program use.  If available, it will attach to the program'
dictionary['CALL'] = 'Statement: Transfers program control to a multiple-line function'
dictionary['CHAIN'] = 'Statement: Loads another program into memory and starts execution'
dictionary['CHR$'] = 'Function: Returns a one character string'
dictionary['CLOSE'] = 'Statement: Closes disk files'
dictionary['COMMAND$'] = 'Function: Returns a string containing the command tail used to execute the program'
dictionary['COMMON'] = 'Statement: Specifies variables to retain in memory for use by chained programs'
dictionary['CONCHAR%'] = 'Function: Reads one character from the console keyboard and returns the decimal ASCII representation of that character'
dictionary['CONSOLE'] = 'Statement: Directs program output to the console screen'
dictionary['CONSTAT%'] = 'Function: Returns a logical value signifying console status'
dictionary['COS'] = 'Function: Returns the cosine of a number'
dictionary['CREATE'] = 'Statement: Creates a new disk file on disk with no information in it'
dictionary['DATA'] = 'Statement: Defines a list of constants that a READ statement can assign to variables'
dictionary['DEF'] = 'Statement: Defines both single-line and multiple-line functions'
dictionary['DELETE'] = 'Statement: Deactivates files from processing and erases them from the disk directory'
dictionary['DETACH'] = 'Statement: Deactivates a printer from program access'
dictionary['DIM'] = 'Statement: Dynamically allocates space for an array'
dictionary['END'] = 'Statement: Terminates a CBASIC program'
dictionary['ERR'] = 'Function: Returns a two-character string signifying the last execution error to occur in a program'
dictionary['ERRL'] = 'Function: Returns the line number in which the last execution error occured'
dictionary['ERRX'] = 'Function: Returns the sixteen-bit MP/M IITM extended error code'
dictionary['EXP'] = 'Function: Returns the constant e raised to an exponent'
dictionary['FEND'] = 'Statement: Terminates multiple-line, user-defined functions'
dictionary['FLOAT'] = 'Function: Converts a number to a floating-point real number'
dictionary['FOR'] = 'Statement: Controls the execution of a FOR/NEXT loop'
dictionary['FRE'] = 'Function: Returns the amount of space available in the Free Storage Area (FSA)'
dictionary['GET'] = 'Function: Reads one byte of data from a specified disk file'
dictionary['GOSUB'] = 'Statement: Execution to the subroutine identified with a statement label'
dictionary['GOTO'] = 'Statement: Transfers execution to a statement identified with a label'
dictionary['IF'] = 'Statement: Transfers execution to one of two statements or statement groups, depending on the value of a logical expression'
dictionary['END'] = 'Statement: Transfers program execution to a specified label when a file access exception occurs'
dictionary['INITIALIZE'] = 'Statement: Allows the user to change diskettes and other removable storage media during program execution without restarting the operating system'
dictionary['INKEY'] = 'Function: Returns the ASCII decimal value equal to a character entrered at the console keyboard'
dictionary['INP'] = 'Function: Returns a value from a CPU input/output port'
dictionary['INPUT'] = 'Statement: Accepts data from the console during program execution and assigns the data to program variables'
dictionary['INPUT LINE'] = 'Statement: Accepts one line of data from the console and assigns it to a string variable'
dictionary['INT'] = 'Function: Returns the integer portion of a number as a floating-point number'
dictionary['INT%'] = 'Function: Returns the integer portion of a number as an integer'
dictionary['INTEGER'] = 'Statement: Declaration statement that specifies the integer data type for variables and function names'
dictionary['LEFT$'] = 'Function: Returns a string consisting of the leftmost characters in a string'
dictionary['LEN'] = 'Function: Returns the length of a string'
dictionary['LET'] = 'Statement: Assigns a value to a variable'
dictionary['LOCK'] = 'Function: Prevents any program from modifying the data in a record'
dictionary['LOG'] = 'Function: Returns the natural logarithm of a number'
dictionary['LPRINTER'] = 'Statement: Directs program output to a printer'
dictionary['MATCH'] = 'Function: Returns the position of the first occurence of a specified character pattern in a string'
dictionary['MFRE'] = 'Function: Returns the largest contiguous area of available memory space in the Free Storage Area (FSA)'
dictionary['MID$'] = 'Function: Returns a segment of a string'
dictionary['MOD'] = 'Function: Returns the remainder form an integer division'
dictionary['NEXT'] = 'Statement: Denotes the end of a FOR/NEXT loop'
dictionary['ON'] = 'Statement: Transfers program execution to one of a number of labels'
dictionary['ON ERROR'] = 'Statement: Branches execution to a label upon detection of an execution error'
dictionary['OPEN'] = 'Statement: Opens an existing disk file for reading or updating'
dictionary['OUT'] = 'Statement: Sends an integer value to a specified CPU output port'
dictionary['PEEK'] = 'Function: Returns the contents of a memory location'
dictionary['POKE'] = 'Statement: Stores one byte of data into a memory location'
dictionary['POS'] = 'Function: Returns the next column position to be printed on the console or printer'
dictionary['PRINT'] = 'Statement: Outputs data to the console or printer'
dictionary['PRINT USING'] = 'Statement: Allows the user to specify special formats for output data.'
dictionary['PRINT #'] = 'Statement: Outputs the data to a disk file'
dictionary['PUT'] = 'Statement: Writes one byte of data to a specified disk file'
dictionary['RANDOMIZE'] = 'Statement: Seeds the random number generator for use with the RND function'
dictionary['READ'] = 'Statement: Sequentially assigns the constants in a DATA statement to variables'
dictionary['READ #'] = 'Statement: Reads data fields from a specified disk file into variables'
dictionary['READ # LINE'] = 'Statement: Reads one complete line of data from a file and assigns the information to a string variable'
dictionary['REAL'] = 'Statement: Declaration statement that specifies a real number data type for variables and function names'
dictionary['REM'] = 'Statement: Documents a source program to improve readability'
dictionary['RENAME'] = 'Function: Allows the user to change the name of a disk file during program execution'
dictionary['RESTORE'] = 'Statement: Allows rereading of the constants in DATA statements'
dictionary['RETURN'] = 'Statement: Transfers control form a subroutine back to the calling program'
dictionary['RIGHT$'] = 'Function: Returns a string consisting of the rightmost characters in a string'
dictionary['RND'] = 'Function: Generates and returns a random number'
dictionary['SADD'] = 'Function: Returns the address of a specified string'
dictionary['SGN'] = 'Function: Returns an integer value representing the algebraic sign of a number'
dictionary['SHIFT'] = 'Function: Returns an integer that is arithmetically shifted a specified number of positions to the right'
dictionary['SIN'] = 'Function: Returns the sine of a number'
dictionary['SIZE'] = 'Function: Returns the number of 1-kilobyte blocks in a specified file'
dictionary['SQR'] = 'Function: Returns the square root of a number'
dictionary['STOP'] = 'Statement: Terminates program execution and returns control to the operating system'
dictionary['STR$'] = 'Function: Converts a number to a string'
dictionary['STRING'] = 'Statement: Declaration statement that specifies a string data type for variables and function names'
dictionary['STRING$'] = 'Function: Returns a string that consists of one string copied a specified number of times'
dictionary['TAB'] = 'Function: Moves the cursor or print head to a specified column'
dictionary['TAN'] = 'Function: Returns the tangent of a number'
dictionary['UCASE$'] = 'Function: Translates lower-case characters to upper-case'
dictionary['UNLOCK'] = 'Function: Unlocks a record, allowing modification of the data in the record'
dictionary['VAL'] = 'Function: Converts a digit string to a real number'
dictionary['VARPTR'] = 'Function: Returns the address of a variable'
dictionary['WEND'] = 'Statement: Denotes the end of a WHILE/WEND loop'
dictionary['WHILE'] = 'Statement: Specifies the conditional expression that controls a WHILE/WEND loop'
dictionary

# %%
# Functions
# dictionary[''] = ''
list = []
list.append({'ABS':'Function: Returns the absolute value of a number'})
list.append({'ASC':'Function: Returns the ASCII decimal value of the first character in a string'})
list.append({'ATN':'Function: Returns the arctangent of a number'})
list.append({'ATTACH':'Function: Returns a Boolean integer value indicating whether or not a specified printer is available for program use.  If available, it will attach to the program'})
list.append({'CALL':'Statement: Transfers program control to a multiple-line function'})
list.append({'CHAIN':'Statement: Loads another program into memory and starts execution'})
list.append({'CHR$':'Function: Returns a one character string'})
list.append({'CLOSE':'Statement: Closes disk files'})
list.append({'COMMAND$':'Function: Returns a string containing the command tail used to execute the program'})
list.append({'COMMON':'Statement: Specifies variables to retain in memory for use by chained programs'})
list.append({'CONCHAR%':'Function: Reads one character from the console keyboard and returns the decimal ASCII representation of that character'})
list.append({'CONSOLE':'Statement: Directs program output to the console screen'})
list.append({'CONSTAT%':'Function: Returns a logical value signifying console status'})
list.append({'COS':'Function: Returns the cosine of a number'})
list.append({'CREATE':'Statement: Creates a new disk file on disk with no information in it'})
list.append({'DATA':'Statement: Defines a list of constants that a READ statement can assign to variables'})
list.append({'DEF':'Statement: Defines both single-line and multiple-line functions'})
list.append({'DELETE':'Statement: Deactivates files from processing and erases them from the disk directory'})
list.append({'DETACH':'Statement: Deactivates a printer from program access'})
list.append({'DIM':'Statement: Dynamically allocates space for an array'})
list.append({'END':'Statement: Terminates a CBASIC program'})
list.append({'ERR':'Function: Returns a two-character string signifying the last execution error to occur in a program'})
list.append({'ERRL':'Function: Returns the line number in which the last execution error occured'})
list.append({'ERRX':'Function: Returns the sixteen-bit MP/M IITM extended error code'})
list.append({'EXP':'Function: Returns the constant e raised to an exponent'})
list.append({'FEND':'Statement: Terminates multiple-line, user-defined functions'})
list.append({'FLOAT':'Function: Converts a number to a floating-point real number'})
list.append({'FOR':'Statement: Controls the execution of a FOR/NEXT loop'})
list.append({'FRE':'Function: Returns the amount of space available in the Free Storage Area (FSA)'})
list.append({'GET':'Function: Reads one byte of data from a specified disk file'})
list.append({'GOSUB':'Statement: Execution to the subroutine identified with a statement label'})
list.append({'GOTO':'Statement: Transfers execution to a statement identified with a label'})
list.append({'IF':'Statement: Transfers execution to one of two statements or statement groups, depending on the value of a logical expression'})
list.append({'END':'Statement: Transfers program execution to a specified label when a file access exception occurs'})
list.append({'INITIALIZE':'Statement: Allows the user to change diskettes and other removable storage media during program execution without restarting the operating system'})
list.append({'INKEY':'Function: Returns the ASCII decimal value equal to a character entrered at the console keyboard'})
list.append({'INP':'Function: Returns a value from a CPU input/output port'})
list.append({'INPUT':'Statement: Accepts data from the console during program execution and assigns the data to program variables'})
list.append({'INPUT LINE':'Statement: Accepts one line of data from the console and assigns it to a string variable'})
list.append({'INT':'Function: Returns the integer portion of a number as a floating-point number'})
list.append({'INT%':'Function: Returns the integer portion of a number as an integer'})
list.append({'INTEGER':'Statement: Declaration statement that specifies the integer data type for variables and function names'})
list.append({'LEFT$':'Function: Returns a string consisting of the leftmost characters in a string'})
list.append({'LEN':'Function: Returns the length of a string'})
list.append({'LET':'Statement: Assigns a value to a variable'})
list.append({'LOCK':'Function: Prevents any program from modifying the data in a record'})
list.append({'LOG':'Function: Returns the natural logarithm of a number'})
list.append({'LPRINTER':'Statement: Directs program output to a printer'})
list.append({'MATCH':'Function: Returns the position of the first occurence of a specified character pattern in a string'})
list.append({'MFRE':'Function: Returns the largest contiguous area of available memory space in the Free Storage Area (FSA)'})
list.append({'MID$':'Function: Returns a segment of a string'})
list.append({'MOD':'Function: Returns the remainder form an integer division'})
list.append({'NEXT':'Statement: Denotes the end of a FOR/NEXT loop'})
list.append({'ON':'Statement: Transfers program execution to one of a number of labels'})
list.append({'ON ERROR':'Statement: Branches execution to a label upon detection of an execution error'})
list.append({'OPEN':'Statement: Opens an existing disk file for reading or updating'})
list.append({'OUT':'Statement: Sends an integer value to a specified CPU output port'})
list.append({'PEEK':'Function: Returns the contents of a memory location'})
list.append({'POKE':'Statement: Stores one byte of data into a memory location'})
list.append({'POS':'Function: Returns the next column position to be printed on the console or printer'})
list.append({'PRINT':'Statement: Outputs data to the console or printer'})
list.append({'PRINT USING':'Statement: Allows the user to specify special formats for output data.'})
list.append({'PRINT #':'Statement: Outputs the data to a disk file'})
list.append({'PUT':'Statement: Writes one byte of data to a specified disk file'})
list.append({'RANDOMIZE':'Statement: Seeds the random number generator for use with the RND function'})
list.append({'READ':'Statement: Sequentially assigns the constants in a DATA statement to variables'})
list.append({'READ #':'Statement: Reads data fields from a specified disk file into variables'})
list.append({'READ # LINE':'Statement: Reads one complete line of data from a file and assigns the information to a string variable'})
list.append({'REAL':'Statement: Declaration statement that specifies a real number data type for variables and function names'})
list.append({'REM':'Statement: Documents a source program to improve readability'})
list.append({'RENAME':'Function: Allows the user to change the name of a disk file during program execution'})
list.append({'RESTORE':'Statement: Allows rereading of the constants in DATA statements'})
list.append({'RETURN':'Statement: Transfers control form a subroutine back to the calling program'})
list.append({'RIGHT$':'Function: Returns a string consisting of the rightmost characters in a string'})
list.append({'RND':'Function: Generates and returns a random number'})
list.append({'SADD':'Function: Returns the address of a specified string'})
list.append({'SGN':'Function: Returns an integer value representing the algebraic sign of a number'})
list.append({'SHIFT':'Function: Returns an integer that is arithmetically shifted a specified number of positions to the right'})
list.append({'SIN':'Function: Returns the sine of a number'})
list.append({'SIZE':'Function: Returns the number of 1-kilobyte blocks in a specified file'})
list.append({'SQR':'Function: Returns the square root of a number'})
list.append({'STOP':'Statement: Terminates program execution and returns control to the operating system'})
list.append({'STR$':'Function: Converts a number to a string'})
list.append({'STRING':'Statement: Declaration statement that specifies a string data type for variables and function names'})
list.append({'STRING$':'Function: Returns a string that consists of one string copied a specified number of times'})
list.append({'TAB':'Function: Moves the cursor or print head to a specified column'})
list.append({'TAN':'Function: Returns the tangent of a number'})
list.append({'UCASE$':'Function: Translates lower-case characters to upper-case'})
list.append({'UNLOCK':'Function: Unlocks a record, allowing modification of the data in the record'})
list.append({'VAL':'Function: Converts a digit string to a real number'})
list.append({'VARPTR':'Function: Returns the address of a variable'})
list.append({'WEND':'Statement: Denotes the end of a WHILE/WEND loop'})
list.append({'WHILE':'Statement: Specifies the conditional expression that controls a WHILE/WEND loop'})
list
# Out:
# [{'ABS': 'Function: Returns the absolute value of a number'},
#  {'ASC': 'Function: Returns the ASCII decimal value of the first character in a string'},
#  {'ATN': 'Function: Returns the arctangent of a number'},
#  {'ATTACH': 'Function: Returns a Boolean integer value indicating whether or not a specified printer is available for program use.  If available, it will attach to the program'},
#  {'CALL': 'Statement: Transfers program control to a multiple-line function'},
#  {'CHAIN': 'Statement: Loads another program into memory and starts execution'},
#  {'CHR$': 'Function: Returns a one character string'},
#  {'CLOSE': 'Statement: Closes disk files'},
#  {'COMMAND$': 'Function: Returns a string containing the command tail used to execute the program'},
#  {'COMMON': 'Statement: Specifies variables to retain in memory for use by chained programs'},
# ...

# %%
# Test Data
program_CBASIC = """
X = ABS(-150)
Y = 100 + 250
Z = X * Y / 3.5

IF X < Y THEN CALL DISPLAY.MESSAGE
IF ABS(X-Y) = 0 THEN CALL WARN.MSG

TEMP.A = 20.5
TEMP.B = TEMP.A + 15.3

IF TEMP.B > 35 THEN CALL COOLING.SYSTEM

VAL = ABS(TEMP.A - TEMP.B)

NAME$ = "JOHN"
"""

# %%
from spacy.vocab import Vocab
vocab = Vocab(strings=program_CBASIC, lex_attr_getters=dictionary)

# %%
print(vocab.strings)

# %%
load_model = spacy.load("en_core_web_sm")
doc = load_model(program_CBASIC)

# %%
doc

# %%
from spacy import displacy
displacy.serve(doc, style="dep")

# %%
sentence_spans = list(doc.sents)
displacy.serve(sentence_spans, style="dep")

# %%
import spacy
from spacy import displacy
# from spacy.tokens import Span

nlp = spacy.blank("en")
doc = nlp(program_CBASIC)

# doc.spans["sc"] = [
#     Span(doc, 3, 6, "ORG"),
#     Span(doc, 5, 6, "GPE"),
# ]

# displacy.serve(doc, style="span")

# %%
# https://www.youtube.com/watch?v=dIUTsFT2MeQ
# 1:41:00 about
# https://spacy.pythonhumanities.com/01_02_linguistic_annotations.html

# %%
nlp.analyze_pipes()

# %%
import spacy
from spacy.matcher import Matcher
# nlp = spacy.load("en_core_web_sm")
nlp = spacy.blank("en")
matcher = Matcher(nlp.vocab)
matcher.add("statement+function", [list])
# pattern = [{"LIKE_EMAIL": True}]
# matcher.add("EMAIL_ADDRESS", [pattern])
# doc = nlp("This is an email address: wmattingly@aol.com")
# matches = matcher(doc)
result = matcher(program_CBASIC, as_spans=True)
# Out:
# ---------------------------------------------------------------------------
# MatchPatternError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_644\346713234.py in <module>
#       4 nlp = spacy.blank("en")
#       5 matcher = Matcher(nlp.vocab)
# ----> 6 matcher.add("statement+function", [list])
#       7 # pattern = [{"LIKE_EMAIL": True}]
#       8 # matcher.add("EMAIL_ADDRESS", [pattern])
#
# ~\anaconda3\lib\site-packages\spacy\matcher\matcher.pyx in spacy.matcher.matcher.Matcher.add()
#
# MatchPatternError: Invalid token patterns for matcher rule 'statement+function'
#
# Pattern 0:
# - [pattern -> 0 -> ABS] extra fields not permitted
# - [pattern -> 1 -> ASC] extra fields not permitted
# - [pattern -> 2 -> ATN] extra fields not permitted
# - [pattern -> 3 -> ATTACH] extra fields not permitted
# - [pattern -> 4 -> CALL] extra fields not permitted
# - [pattern -> 5 -> CHAIN] extra fields not permitted
# ...

# %%
import spacy
from spacy.matcher import Matcher
from spacy.tokens import Span

nlp = spacy.blank("en")
matcher = Matcher(nlp.vocab)
matcher.add("statement+function", [list])
doc = nlp("Barack Obama was the 44th president of the United States")

# 1. Return (match_id, start, end) tuples
matches = matcher(doc)
for match_id, start, end in matches:
    # Create the matched span and assign the match_id as a label
    span = Span(doc, start, end, label=match_id)
    print(span.text, span.label_)

# 2. Return Span objects directly
matches = matcher(doc, as_spans=True)
for span in matches:
    print(span.text, span.label_)
# Out:
# ---------------------------------------------------------------------------
# MatchPatternError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_644\199221799.py in <module>
#       5 nlp = spacy.blank("en")
#       6 matcher = Matcher(nlp.vocab)
# ----> 7 matcher.add("statement+function", [list])
#       8 doc = nlp("Barack Obama was the 44th president of the United States")
#       9
#
# ~\anaconda3\lib\site-packages\spacy\matcher\matcher.pyx in spacy.matcher.matcher.Matcher.add()
#
# MatchPatternError: Invalid token patterns for matcher rule 'statement+function'
#
# Pattern 0:
# - [pattern -> 0 -> ABS] extra fields not permitted
# - [pattern -> 1 -> ASC] extra fields not permitted
# - [pattern -> 2 -> ATN] extra fields not permitted
# - [pattern -> 3 -> ATTACH] extra fields not permitted
# - [pattern -> 4 -> CALL] extra fields not permitted
# - [pattern -> 5 -> CHAIN] extra fields not permitted
# ...

# %%
# https://www.analyticsvidhya.com/blog/2021/06/nlp-application-named-entity-recognition-ner-in-python-with-spacy/
